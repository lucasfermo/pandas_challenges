# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_iris
from pandas_datareader.data import DataReader
from mpl_toolkits import mplot3d
from matplotlib import dates as date
import seaborn as sns; sns.set() 
from scipy import stats
from datetime import datetime
plt.style.use("fivethirtyeight")

# %%
#Import dataset
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris=pd.read_csv(url)

# %%
#Create columns in the dataset
col=["sepal_length","sepal_width",'petal_length','petal_width','class']
iris.columns=col

# %%
#Any NaN values?
iris.isnull().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# class           False
# dtype: bool

# %%
#Channge values of rows 10 to 29 in column petal_length to NaN
iris.loc[10:29,'petal_length']=None

# %%
#Delete the column class
del iris['class']

# %%
#Set first 3 rows to NaN
iris.iloc[:3]=None

# %%
#Delete the rows that have NaN
iris=iris.dropna(axis=0)

# %%
#Reset index so it begins with 0
iris.reset_index()
# Out:
#      index  sepal_length  sepal_width  petal_length  petal_width
# 0        3           5.0          3.6           1.4          0.2
# 1        4           5.4          3.9           1.7          0.4
# 2        5           4.6          3.4           1.4          0.3
# 3        6           5.0          3.4           1.5          0.2
# 4        7           4.4          2.9           1.4          0.2
# 5        8           4.9          3.1           1.5          0.1
# 6        9           5.4          3.7           1.5          0.2
# 7       30           5.4          3.4           1.5          0.4
# 8       31           5.2          4.1           1.5          0.1
# 9       32           5.5          4.2           1.4          0.2
# 10      33           4.9          3.1           1.5          0.1
# 11      34           5.0          3.2           1.2          0.2
# 12      35           5.5          3.5           1.3          0.2
# ...
